# %% [markdown]
# # Image encoding

# %% [markdown]
# ## Preparing the dataset
# Make sure your dataset is divided in three folders: "train", "test", and "val". In each of these folders, there should be three sub-folders: chips and labels. In these two sub-folders there should be matching patches of PATHC_SIZE x PATCH_SIZE and format ".npy". Matching objects should have the same name, replacing "naip-new"(in the patches) by "lc"(in the labels).
#
# If following this tutorial, directory structure should look like:
# ```
# data/
# └── cvpr/
#     ├── files/
#     │   ├── train/
#     │   ├── val/
#     │   └── test/
#     └── ny/
#         ├── train/
#         │   ├── chips/
#         │   └── labels/
#         ├── val/
#         │   ├── chips/
#         │   └── labels/
#         └── test/
#             ├── chips/
#             └── labels/
# ```

# %% [markdown]
# ## Using the model
#
# 1. Download the Clay model checkpoint from [Huggingface model hub](https://huggingface.co/made-with-clay/Clay/blob/main/v1.5/clay-v1.5.ckpt) and save it in the `checkpoints/` directory.
#
# 2. Run the model. Configuration file can be found in `configs/extract_embeddings_chesapeake.yaml`. Beaware, the function Encode_images_from_config needs to be run for all three folders "train", "val" and "test". For this you will need to modify the fields "predict_chip_dir", "predict_label_dir" and "output_dir" from the configuration file.

# %%
import os
import shutil
import subprocess
from pathlib import Path

def find_project_root(marker='claymodel'):
    current = Path.cwd()
    for path in [current] + list(current.parents):
        if (path / marker).exists():
            return path
    raise FileNotFoundError(f"Project root not found")

os.chdir(find_project_root())
print(f"Current working directory: {os.getcwd()}")

MODEL_DIR = "checkpoints/"
CHECKPOINT_FILENAME = "clay-v1.5.ckpt"
# CHECKPOINT_FILENAME = "Prithvi_EO_V2_300M.pt"

full_target_path = os.path.join(MODEL_DIR, CHECKPOINT_FILENAME)

if os.path.exists(full_target_path):
    print(f"✓ File already exists at: {full_target_path}")
else:
    print(f"✗ File not found at: {full_target_path}")
    
    if CHECKPOINT_FILENAME != "clay-v1.5.ckpt":
        print("Please download the model.")
        exit(1)

    print("Downloading checkpoint...")
    
    # Create target directory if it doesn't exist
    os.makedirs(MODEL_DIR, exist_ok=True)
    
    try:
        # Download the file using wget
        download_url = "https://huggingface.co/made-with-clay/Clay/resolve/main/v1.5/clay-v1.5.ckpt"
        result = subprocess.run(
            ["wget", "-q", download_url],
            check=True,
            capture_output=True,
            text=True
        )
        
        # Move the downloaded file to the target location
        if os.path.exists(CHECKPOINT_FILENAME):
            shutil.move(CHECKPOINT_FILENAME, full_target_path)
            print(f"✓ Successfully downloaded and moved to: {full_target_path}")
        else:
            print("✗ Download failed - file not found after wget")
            
    except subprocess.CalledProcessError as e:
        print(f"Error downloading file: {e}")
        print(f"Error output: {e.stderr}")
    except Exception as e:
        print(f"Unexpected error: {str(e)}")
# Out:
# Current working directory: /home/ignacio/Code/Clay-foundation/model
# ✓ File already exists at: checkpoints/clay-v1.5.ckpt

# %%
from lightning.pytorch import Trainer, seed_everything
from lightning.pytorch.cli import LightningArgumentParser, instantiate_class

from claymodel.finetune.boundary_detection.embedding_extractor import ClayEmbeddingExtractor
from claymodel.finetune.boundary_detection.ai4b_datamodule import AI4BDataModule

seed_everything(42)  # your seed here

def Encode_images_from_config(config_path, dataset="train"):
    
    parser = LightningArgumentParser()
    parser.add_lightning_class_args(ClayEmbeddingExtractor, "model")
    parser.add_lightning_class_args(AI4BDataModule, "data")
    parser.add_lightning_class_args(Trainer, "trainer")
    
    config = parser.parse_path(config_path)
    trainer_config = dict(config["trainer"])
    
    callbacks = []
    for callback_config in trainer_config["callbacks"]:
        if hasattr(callback_config, 'class_path') and hasattr(callback_config, 'init_args'):
            # This is a Namespace object from CLI parsing
            callback_config.init_args["model_path"] = config["model"]["ckpt_path"].replace('/', '_').split('.')[0]
            callback = instantiate_class((), callback_config)
            callbacks.append(callback)
        elif isinstance(callback_config, dict) and "class_path" in callback_config:
            # This is a dictionary configuration
            callback_config["model_path"] = config["model"]["ckpt_path"].replace('/', '_').split('.')[0]    
            callback = instantiate_class((), callback_config)
            callbacks.append(callback)
        else:
            # Already an instantiated callback
            callbacks.append(callback_config)
    
    print(callback_config)
    trainer_config["callbacks"] = callbacks        
    
    # Create instances
    model = ClayEmbeddingExtractor(**config["model"])
    config["data"]["predict_ds"] = dataset
    datamodule = AI4BDataModule(**config["data"])
    trainer = Trainer(**trainer_config)

    trainer.predict(model, datamodule)   

    return config
# Out:
# Seed set to 42

# %%
CONFIG_PATH = 'configs/extract_embeddings_ai4b.yaml'
#available_datasets = ["train", "val", "test"]
available_datasets = ["val"]

for ds in available_datasets:
    print(f"Encoding dataset: {ds}")
    Encode_images_from_config(CONFIG_PATH, dataset=ds)
# Out:
# Encoding dataset: val
# 🗜️  Saving in float16
# Namespace(class_path='claymodel.finetune.segment.embedding_callback.EmbeddingSaveCallback', init_args=Namespace(save_metadata=True, compression=False, compressed_quantization=True, model_path='checkpoints_clay-v1'))
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✅ Clay model loaded from: checkpoints/clay-v1.5.ckpt
# 🔒 Encoder frozen: True
# 🚀 Starting embedding extraction...
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 💾 Saving embeddings for batch 0 (shape: (8, 6, 1024, 1024))
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:928, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     925 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     926     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     927 )
# --> 928 results = self._run(model, ckpt_path=ckpt_path)
#     930 assert self.state.stopped
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:1012, in Trainer._run(self, model, ckpt_path)
#    1009 # ----------------------------
#    1010 # RUN THE TRAINER
#    1011 # ----------------------------
# -> 1012 results = self._run_stage()
#    1014 # ----------------------------
#    1015 # POST-Training CLEAN UP
#    1016 # ----------------------------
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:1051, in Trainer._run_stage(self)
#    1050 if self.predicting:
# -> 1051     return self.predict_loop.run()
#    1052 if self.training:
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/loops/utilities.py:179, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     178 with context_manager():
# --> 179     return loop_run(self, *args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/loops/prediction_loop.py:125, in _PredictionLoop.run(self)
#     124     # run step hooks
# --> 125     self._predict_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     126 except StopIteration:
#     127     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/loops/prediction_loop.py:255, in _PredictionLoop._predict_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     250 step_args = (
#     251     self._build_step_args_from_hook_kwargs(hook_kwargs, "predict_step")
#     252     if not using_dataloader_iter
#     253     else (dataloader_iter,)
#     254 )
# --> 255 predictions = call._call_strategy_hook(trainer, "predict_step", *step_args)
#     256 if predictions is None:
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:328, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 328     output = fn(*args, **kwargs)
#     330 # restore current_fx when nested context
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py:438, in Strategy.predict_step(self, *args, **kwargs)
#     437     return self._forward_redirection(self.model, self.lightning_module, "predict_step", *args, **kwargs)
# --> 438 return self.lightning_module.predict_step(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/claymodel/finetune/boundary_detection/embedding_extractor.py:93, in ClayEmbeddingExtractor.predict_step(self, batch, batch_idx, dataloader_idx)
#      92 # Get embeddings
# ---> 93 embeddings = self(x)
#      95 return {
#      96     'embeddings': embeddings,
#      97     'batch_idx': batch_idx,
#    (...)    100     'chip_names': batch["chip_name"]
#     101 }
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/claymodel/finetune/boundary_detection/embedding_extractor.py:68, in ClayEmbeddingExtractor.forward(self, x)
#      67 with torch.no_grad():
# ---> 68     unmsk_patch, *_ = self.clay_encoder(x_t)
#      70 if self.cls:
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/claymodel/model.py:203, in Encoder.forward(self, datacube)
#     202 # pass the unmasked patches through the transformer
# --> 203 encoded_unmasked_patches = self.transformer(
#     204     unmasked_patches
#     205 )  # [B ((1 + L)):(1 - mask_ratio)) D]
#     207 return (
#     208     encoded_unmasked_patches,
#     209     unmasked_indices,
#     210     masked_indices,
#     211     masked_matrix,
#     212 )
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/claymodel/backbone.py:82, in Transformer.forward(self, x)
#      81     x = attn(x) + x
# ---> 82     x = ff(x) + x
#      83 return self.norm(x)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/claymodel/backbone.py:22, in FeedForward.forward(self, x)
#      21 def forward(self, x):
# ---> 22     return self.net(x)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     243 for module in self:
# --> 244     input = module(input)
#     245 return input
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 for ds in available_datasets:
#       6     print(f"Encoding dataset: {ds}")
# ----> 7     Encode_images_from_config(CONFIG_PATH, dataset=ds)
#
# Cell In[2], line 44, in Encode_images_from_config(config_path, dataset)
#      41 datamodule = AI4BDataModule(**config["data"])
#      42 trainer = Trainer(**trainer_config)
# ---> 44 trainer.predict(model, datamodule)
#      46 return config
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:887, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     885 self.state.status = TrainerStatus.RUNNING
#     886 self.predicting = True
# --> 887 return call._call_and_handle_interrupt(
#     888     self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     889 )
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:65, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63     if isinstance(launcher, _SubprocessScriptLauncher):
#      64         launcher.kill(_get_sigkill_signal())
# ---> 65     exit(1)
#      67 except BaseException as exception:
#      68     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined
