# %% [markdown]
# # Image encoding

# %% [markdown]
# ## Preparing the dataset
# Make sure your dataset is divided in three folders: "train", "test", and "val". In each of these folders, there should be three sub-folders: chips and labels. In these two sub-folders there should be matching patches of PATHC_SIZE x PATCH_SIZE and format ".npy". Matching objects should have the same name, replacing "naip-new"(in the patches) by "lc"(in the labels).
#
# If following this tutorial, directory structure should look like:
# ```
# data/
# └── cvpr/
#     ├── files/
#     │   ├── train/
#     │   ├── val/
#     │   └── test/
#     └── ny/
#         ├── train/
#         │   ├── chips/
#         │   └── labels/
#         ├── val/
#         │   ├── chips/
#         │   └── labels/
#         └── test/
#             ├── chips/
#             └── labels/
# ```

# %% [markdown]
# ## Using the model
#
# 1. Download the Clay model checkpoint from [Huggingface model hub](https://huggingface.co/made-with-clay/Clay/blob/main/v1.5/clay-v1.5.ckpt) and save it in the `checkpoints/` directory.
#
# 2. Run the model. Configuration file can be found in `configs/extract_embeddings_chesapeake.yaml`. Beaware, the function Encode_images_from_config needs to be run for all three folders "train", "val" and "test". For this you will need to modify the fields "predict_chip_dir", "predict_label_dir" and "output_dir" from the configuration file.

# %%
import os
import shutil
import subprocess
from pathlib import Path

def find_project_root(marker='claymodel'):
    current = Path.cwd()
    for path in [current] + list(current.parents):
        if (path / marker).exists():
            return path
    raise FileNotFoundError(f"Project root not found")

os.chdir(find_project_root())
print(f"Current working directory: {os.getcwd()}")

MODEL_DIR = "checkpoints/"
CHECKPOINT_FILENAME = "clay-v1.5.ckpt"
# CHECKPOINT_FILENAME = "Prithvi_EO_V2_300M.pt"

full_target_path = os.path.join(MODEL_DIR, CHECKPOINT_FILENAME)

if os.path.exists(full_target_path):
    print(f"✓ File already exists at: {full_target_path}")
else:
    print(f"✗ File not found at: {full_target_path}")
    
    if CHECKPOINT_FILENAME is not "clay-v1.5.ckpt":
        print("Please download the model.")
        exit(1)

    print("Downloading checkpoint...")
    
    # Create target directory if it doesn't exist
    os.makedirs(MODEL_DIR, exist_ok=True)
    
    try:
        # Download the file using wget
        download_url = "https://huggingface.co/made-with-clay/Clay/resolve/main/v1.5/clay-v1.5.ckpt"
        result = subprocess.run(
            ["wget", "-q", download_url],
            check=True,
            capture_output=True,
            text=True
        )
        
        # Move the downloaded file to the target location
        if os.path.exists(CHECKPOINT_FILENAME):
            shutil.move(CHECKPOINT_FILENAME, full_target_path)
            print(f"✓ Successfully downloaded and moved to: {full_target_path}")
        else:
            print("✗ Download failed - file not found after wget")
            
    except subprocess.CalledProcessError as e:
        print(f"Error downloading file: {e}")
        print(f"Error output: {e.stderr}")
    except Exception as e:
        print(f"Unexpected error: {str(e)}")
# Out:
# Current working directory: /home/ignacio/Code/Clay-foundation/model
# ✓ File already exists at: checkpoints/Prithvi_EO_V2_300M.pt
# <>:27: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# <>:27: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /tmp/ipykernel_127129/2364141766.py:27: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if CHECKPOINT_FILENAME is not "clay-v1.5.ckpt":

# %%
from lightning.pytorch import Trainer, seed_everything
from lightning.pytorch.cli import LightningArgumentParser, instantiate_class

from claymodel.finetune.segment.embedding_extractor import ClayEmbeddingExtractor
from claymodel.finetune.segment.chesapeake_datamodule_v2 import ChesapeakeDataModule

seed_everything(42)  # your seed here

def Encode_images_from_config(config_path, dataset="train"):
    
    parser = LightningArgumentParser()
    parser.add_lightning_class_args(ClayEmbeddingExtractor, "model")
    parser.add_lightning_class_args(ChesapeakeDataModule, "data")
    parser.add_lightning_class_args(Trainer, "trainer")
    
    config = parser.parse_path(config_path)
    trainer_config = dict(config["trainer"])
    
    callbacks = []
    for callback_config in trainer_config["callbacks"]:
        if hasattr(callback_config, 'class_path') and hasattr(callback_config, 'init_args'):
            # This is a Namespace object from CLI parsing
            callback_config.init_args["model_path"] = config["model"]["ckpt_path"].replace('/', '_').split('.')[0]
            callback = instantiate_class((), callback_config)
            callbacks.append(callback)
        elif isinstance(callback_config, dict) and "class_path" in callback_config:
            # This is a dictionary configuration
            callback_config["model_path"] = config["model"]["ckpt_path"].replace('/', '_').split('.')[0]    
            callback = instantiate_class((), callback_config)
            callbacks.append(callback)
        else:
            # Already an instantiated callback
            callbacks.append(callback_config)
    
    print(callback_config)
    trainer_config["callbacks"] = callbacks        
    
    # Create instances
    model = ClayEmbeddingExtractor(**config["model"])
    config["data"]["predict_ds"] = dataset
    datamodule = ChesapeakeDataModule(**config["data"])
    trainer = Trainer(**trainer_config)

    trainer.predict(model, datamodule)   

    return config
# Out:
# Seed set to 42

# %%
CONFIG_PATH = 'configs/extract_embeddings_chesapeake.yaml'
# available_datasets = ["train", "val", "test"]
available_datasets = ["test"]

for ds in available_datasets:
    print(f"Encoding dataset: {ds}")
    Encode_images_from_config(CONFIG_PATH, dataset=ds)
# Out:
# Encoding dataset: test
# 🗜️  Saving in float16
# Namespace(class_path='claymodel.finetune.segment.embedding_callback.EmbeddingSaveCallback', init_args=Namespace(save_metadata=True, compression=False, compressed_quantization=True, model_path='checkpoints_Prithvi_EO_V2_300M'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 7
#       5 for ds in available_datasets:
#       6     print(f"Encoding dataset: {ds}")
# ----> 7     Encode_images_from_config(CONFIG_PATH, dataset=ds)
#
# Cell In[2], line 39, in Encode_images_from_config(config_path, dataset)
#      36 trainer_config["callbacks"] = callbacks
#      38 # Create instances
# ---> 39 model = ClayEmbeddingExtractor(**config["model"])
#      40 config["data"]["predict_ds"] = dataset
#      41 datamodule = ChesapeakeDataModule(**config["data"])
#
# File ~/Code/Clay-foundation/model/claymodel/finetune/segment/embedding_extractor.py:29, in ClayEmbeddingExtractor.__init__(self, ckpt_path, freeze_encoder, cls)
#      22 self.cls = cls
#      23 # if cls:
#      24 #     mask_ratio = 0.0
#      25 # else:
#      26 #     mask_ratio = 0.0
#      27
#      28 # Load the Clay model
# ---> 29 self.clay_encoder = ClayMAEModule.load_from_checkpoint(
#      30     ckpt_path,
#      31     strict=False,
#      32     model_size="large",
#      33     dolls=[16, 32, 64, 128, 256, 768, 1024],
#      34     doll_weights=[1]*7,
#      35     mask_ratio=0.0,
#      36     shuffle=False
#      37 ).model.encoder
#      39 if freeze_encoder:
#      40     # Freeze all parameters for inference
#      41     for param in self.clay_encoder.parameters():
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/model_helpers.py:125, in _restricted_classmethod_impl.__get__.<locals>.wrapper(*args, **kwargs)
#     120 if instance is not None and not is_scripting:
#     121     raise TypeError(
#     122         f"The classmethod `{cls.__name__}.{self.method.__name__}` cannot be called on an instance."
#     123         " Please call it on the class type and make sure the return value is used."
#     124     )
# --> 125 return self.method(cls, *args, **kwargs)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/core/module.py:1662, in LightningModule.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#    1573 @_restricted_classmethod
#    1574 def load_from_checkpoint(
#    1575     cls,
#    (...)   1580     **kwargs: Any,
#    1581 ) -> Self:
#    1582     r"""Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint it stores the arguments
#    1583     passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    1584
#    (...)   1660
#    1661     """
# -> 1662     loaded = _load_from_checkpoint(
#    1663         cls,
#    1664         checkpoint_path,
#    1665         map_location,
#    1666         hparams_file,
#    1667         strict,
#    1668         **kwargs,
#    1669     )
#    1670     return cast(Self, loaded)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/core/saving.py:66, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      63     checkpoint = pl_load(checkpoint_path, map_location=map_location)
#      65 # convert legacy checkpoints to the new format
# ---> 66 checkpoint = _pl_migrate_checkpoint(
#      67     checkpoint, checkpoint_path=(checkpoint_path if isinstance(checkpoint_path, (str, Path)) else None)
#      68 )
#      70 if hparams_file is not None:
#      71     extension = str(hparams_file).split(".")[-1]
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/migration/utils.py:143, in _pl_migrate_checkpoint(checkpoint, checkpoint_path)
#     137 def _pl_migrate_checkpoint(checkpoint: _CHECKPOINT, checkpoint_path: Optional[_PATH] = None) -> _CHECKPOINT:
#     138     """Applies Lightning version migrations to a checkpoint dictionary and prints infos for the user.
#     139
#     140     This function is used by the Lightning Trainer when resuming from a checkpoint.
#     141
#     142     """
# --> 143     old_version = _get_version(checkpoint)
#     144     checkpoint, migrations = migrate_checkpoint(checkpoint)
#     145     new_version = _get_version(checkpoint)
#
# File ~/Code/Clay-foundation/model/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/migration/utils.py:164, in _get_version(checkpoint)
#     162 def _get_version(checkpoint: _CHECKPOINT) -> str:
#     163     """Get the version of a Lightning checkpoint."""
# --> 164     return checkpoint["pytorch-lightning_version"]
#
# KeyError: 'pytorch-lightning_version'
